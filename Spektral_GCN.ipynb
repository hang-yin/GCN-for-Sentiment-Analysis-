# %% [markdown]
# # GCN on Node Classification

# %% [markdown]
# ## Dependencies and import

# %%
# !pip install --quiet spektral
# !pip install --quiet neural_structured_learning
# !pip install --quiet tensorflow_hub
# !pip install --quiet tensorflow-text

# %%
"""
This example implements the experiments on citation networks from the paper:
Semi-Supervised Classification with Graph Convolutional Networks (https://arxiv.org/abs/1609.02907)
Thomas N. Kipf, Max Welling
"""
import numpy as np
import tensorflow as tf
import os
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop


from spektral.data.loaders import SingleLoader
from spektral.datasets.citation import Citation
from spektral.layers import GCNConv
from spektral.models.gcn import GCN
from spektral.transforms import LayerPreprocess

from spektral.data import Graph
from spektral.data import Dataset
from spektral.transforms import GCNFilter
import pandas as pd
from spektral.utils.sparse import sp_matrix_to_sp_tensor

# %%
import neural_structured_learning as nsl

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text

# %%
tf.keras.backend.clear_session()

print("Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("Hub version: ", hub.__version__)
print(
    "GPU is",
    "available" if tf.config.list_physical_devices("GPU") else "NOT AVAILABLE")
# Out:
# Version:  2.9.1
# Eager mode:  True
# Hub version:  0.12.0
# GPU is NOT AVAILABLE

# %% [markdown]
# ## Load data

# %%
# Load data
# dataset = Citation(data, normalize_x=True, transforms=[LayerPreprocess(GCNConv)])
imdb = tf.keras.datasets.imdb
(pp_train_data, pp_train_labels), (pp_test_data, pp_test_labels) = (
    imdb.load_data(num_words=10000))

# %%
# This block limits how much is loaded to keep debugging short
# don't run on the final experiments

limit = 1000

pp_train_data = pp_train_data[0:limit]
pp_train_labels = pp_train_labels[0:limit]
pp_test_data = pp_test_data[0:limit]
pp_test_labels = pp_test_labels[0:limit]

# %%
print('Training entries: {}, labels: {}'.format(
    len(pp_train_data), len(pp_train_labels)))
training_samples_count = len(pp_train_data)
# Out:
# Training entries: 1000, labels: 1000

# %%
print(pp_train_data[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
len(pp_train_data[0]), len(pp_train_data[1])
# Out:
# (218, 189)

# %%
def sampleFunction(inputFeature):
    """
    This is a description of the function
    
    Args:
        inputFeature - (np.ndarray) This is what the feature is
    Returns:
        result - (int) This is what is returned
    """

    result = 55
    return result

def buildReverseWordIndex(dataset):
    """
    Convert the index back to words with proper accounting for 
    the special characters reserved at the beginning of the dictionary

    Args: 
        dataset - (keras.dataset) The dataset to use
    Returns:
        buildReverseWordIndex - (dict) A dictionary mapping words to an integer index
    """
    wordIndex = dataset.get_word_index()

    # The first indices are reserved
    wordIndex = {k: (v + 3) for k, v in wordIndex.items()}
    wordIndex['<PAD>'] = 0
    wordIndex['<START>'] = 1
    wordIndex['<UNK>'] = 2  # unknown
    wordIndex['<UNUSED>'] = 3
    return dict((value, key) for (key, value) in wordIndex.items())

def decodeReview(text, reverseWordIndex):
    """
    Uses build_reverse_word_index to decode original data format into text
    
    Args:
        text - (np.ndarray) The text to decode
        reverseWordIndex - (dict) The reverse word index to use
    Returns:
        decodedReview - (string) The decoded review
    """
    return ' '.join([reverseWordIndex.get(i, '?') for i in text])

# %%
reverseWordIndex = buildReverseWordIndex(imdb)
decodeReview(pp_train_data[0], reverseWordIndex)
# Out:
# "<START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little boy's that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %% [markdown]
# ## Generate BERT Embedding

# %%
pretrained_embedding = 'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/2'

# %%
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)
preprocessor = hub.KerasLayer(
    'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3')

# %%
encoder_inputs = preprocessor(text_input)

encoder = hub.KerasLayer(
    'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/2',
    trainable=True)

outputs = encoder(encoder_inputs)

pooled_output = outputs['pooled_output'] # [batch_size, 128].
# [batch_size, seq_length, 128].

sequence_output = outputs['sequence_output']

# %%
def int64Feature(value):
    """
    Returns int64 tf.train.Feature.

    Args:
        value - (np.ndarray) array of ints
    """
    return tf.train.Feature(int64_list=tf.train.Int64List(value=value.tolist()))


def bytesFeature(value):
    """
    Returns bytes tf.train.Feature.

    Args:
        value - (string) string
    """
    return tf.train.Feature(
        bytes_list=tf.train.BytesList(value=[value.encode('utf-8')]))


def floatFeature(value):
    """
    Returns float tf.train.Feature.

    Args:
        value - (np.ndarray) array of floats

    """
    return tf.train.Feature(float_list=tf.train.FloatList(value=value.tolist()))

# %%
def createBertEmbeddingExample(wordVector, recordID, reverseWordIndex, encoder, preprocessor):
    """
    Create tf.Example containing the sample's embedding and its ID.
    
    Args:
        wordVector - (np.ndarray) the text to decode
        recordId - (int) ID of the sample
        reverseWordIndex - (dict) The reverse word index to use
        encoder - (string) encoder name
        preprocessor - (string) preprocessor name
    Returns:
        example - (tf.Example) tf.Example containing the sample's embedding and its ID
    """

    text = decodeReview(wordVector, reverseWordIndex)

    # Shape = [batch_size,].
    sentenceEmbedding = encoder(preprocessor(tf.reshape(text, shape=[-1, ])))['pooled_output']
    
    # Flatten the sentence embedding back to 1-D.
    sentenceEmbedding = tf.reshape(sentenceEmbedding, shape=[-1])
    
    features = {
        'id': bytesFeature(str(recordID)),
        'embedding': floatFeature(sentenceEmbedding.numpy())
    }
    return tf.train.Example(features=tf.train.Features(feature=features))


def createBertEmbedding(wordVectors, outputPath, startingRecordId, reverseWordIndex, encoder, preprocessor):
    """
    Create full set of BERT embeddings

    Args:
        wordVectors - (np.ndarray) all text to decode
        outputPath - (string) path to output file
        startingRecordId - (int) ID of the first sample
        reverseWordIndex - (dict) The reverse word index to use
        encoder - (string) encoder name
        preprocessor - (string) preprocessor name
    Returns:
        recordID - (int) ID of the last sample
    """
    recordID = int(startingRecordId)
    with tf.io.TFRecordWriter(outputPath) as writer:
        for word_vector in wordVectors:
            example = createBertEmbeddingExample(word_vector, recordID, reverseWordIndex, encoder, preprocessor)
            recordID = recordID + 1
            writer.write(example.SerializeToString())
    return recordID

# %%
# !mkdir /tmp/imdb
# Out:
# mkdir: cannot create directory ‘/tmp/imdb’: File exists

# %%
# Generate full BERT embeddings

bertEmbeddingsPath = '/tmp/imdb/bertEmeddings.tfr'
createBertEmbedding(pp_train_data, bertEmbeddingsPath, 0, reverseWordIndex, encoder, preprocessor)
# Out:
# 1000

# %%
# !wc -l /tmp/imdb/bertEmeddings.tfr
# Out:
# 9329 /tmp/imdb/bertEmeddings.tfr

# %%
def createBertEmbeddingExample_tf(wordVector, reverseWordIndex, encoder, preprocessor):
    """
    Create tf.Example containing the sample's embedding and its ID.
    
    Args:
        wordVector - (np.ndarray) the text to decode
        recordId - (int) ID of the sample
        reverseWordIndex - (dict) The reverse word index to use
        encoder - (string) encoder name
        preprocessor - (string) preprocessor name
    Returns:
        example - (tf.Example) tf.Example containing the sample's embedding and its ID
    """

    text = decodeReview(wordVector, reverseWordIndex)

    # Shape = [batch_size,].
    sentenceEmbedding = encoder(preprocessor(tf.reshape(text, shape=[-1, ])))['pooled_output']
    
    # Flatten the sentence embedding back to 1-D.
    sentenceEmbedding = tf.reshape(sentenceEmbedding, shape=[-1])
    
    # features = {
    #     'id': bytesFeature(str(recordID)),
    #     'embedding': floatFeature(sentenceEmbedding.numpy())
    # }
    # return tf.train.Example(features=tf.train.Features(feature=features))
    return sentenceEmbedding

def createBertEmbedding_tf(wordVectors, reverseWordIndex, encoder, preprocessor):
    """
    Create full set of BERT embeddings

    Args:
        wordVectors - (np.ndarray) all text to decode
        outputPath - (string) path to output file
        startingRecordId - (int) ID of the first sample
        reverseWordIndex - (dict) The reverse word index to use
        encoder - (string) encoder name
        preprocessor - (string) preprocessor name
    Returns:
        recordID - (int) ID of the last sample
    """
    sentenceEmbeddings = []
    for word_vector in wordVectors:
        example = createBertEmbeddingExample_tf(word_vector, reverseWordIndex, encoder, preprocessor)
        sentenceEmbeddings.append(example)
    sentenceEmbeddings_np = np.array(sentenceEmbeddings)
    return sentenceEmbeddings_np

# %%
bertEmbeddings_np = createBertEmbedding_tf(pp_train_data, reverseWordIndex, encoder, preprocessor)
bertEmbeddings_np
# Out:
# array([[-0.99705344,  0.13148627, -0.9839852 , ...,  0.46490347,
#          0.9740655 ,  0.9860606 ],
#        [-0.99880314, -0.01381373, -0.94920063, ...,  0.7923372 ,
#          0.963446  ,  0.9852994 ],
#        [-0.9977645 ,  0.08967871, -0.99587804, ...,  0.7926493 ,
#          0.9919198 ,  0.98849094],
#        ...,
#        [-0.99963784,  0.01017996, -0.9731926 , ...,  0.8962663 ,
#          0.9838081 ,  0.90645903],
#        [-0.99953955, -0.00890382, -0.7950634 , ...,  0.6752377 ,
#          0.9756713 ,  0.94408995],
#        [-0.99809605,  0.03867956, -0.98139894, ..., -0.70533836,
#          0.990776  ,  0.9948569 ]], dtype=float32)

# %%
np.shape(bertEmbeddings_np)
# Out:
# (1000, 128)

# %% [markdown]
# ## Construct Graph Using Swivel Embedding

# %%
# !mkdir -p /tmp/imdb

# %%
pretrained_embedding = 'https://tfhub.dev/google/tf2-preview/gnews-swivel-20dim/1'

hub_layer = hub.KerasLayer(
    pretrained_embedding, input_shape=[], dtype=tf.string, trainable=True)

# %%
def create_embedding_example(word_vector, record_id):
  """Create tf.Example containing the sample's embedding and its ID."""

  text = decodeReview(word_vector, reverseWordIndex)

  # Shape = [batch_size,].
  sentence_embedding = hub_layer(tf.reshape(text, shape=[-1,]))

  # Flatten the sentence embedding back to 1-D.
  sentence_embedding = tf.reshape(sentence_embedding, shape=[-1])

  features = {
      'id': bytesFeature(str(record_id)),
      'embedding': floatFeature(sentence_embedding.numpy())
  }
  return tf.train.Example(features=tf.train.Features(feature=features))


def create_embeddings(word_vectors, output_path, starting_record_id):
  record_id = int(starting_record_id)
  with tf.io.TFRecordWriter(output_path) as writer:
    for word_vector in word_vectors:
      example = create_embedding_example(word_vector, record_id)
      record_id = record_id + 1
      writer.write(example.SerializeToString())
  return record_id


# Persist TF.Example features containing embeddings for training data in
# TFRecord format.
create_embeddings(pp_train_data, '/tmp/imdb/embeddings.tfr', 0)
# Out:
# 1000

# %%
graph_builder_config = nsl.configs.GraphBuilderConfig(
    similarity_threshold=0.99, lsh_splits=32, lsh_rounds=15, random_seed=42)
nsl.tools.build_graph_from_config(['/tmp/imdb/embeddings.tfr'],
                                  '/tmp/imdb/graph_99.tsv',
                                  graph_builder_config)

# %%
# !wc -l /tmp/imdb/graph_99.tsv
# Out:
# 1486 /tmp/imdb/graph_99.tsv

# %% [markdown]
# ## Construct Graph Using BERT Embedding

# %%
graph_builder_config = nsl.configs.GraphBuilderConfig(
    similarity_threshold=0.99, lsh_splits=32, lsh_rounds=15, random_seed=42)
nsl.tools.build_graph_from_config(['/tmp/imdb/bertEmeddings.tfr'],
                                  '/tmp/imdb/graph_99.tsv',
                                  graph_builder_config)

# %%
# !wc -l /tmp/imdb/graph_99.tsv
# Out:
# 60 /tmp/imdb/graph_99.tsv

# %% [markdown]
# ## Convert NSL Graph to Spektral Graph

# %%
df = pd.read_csv('/tmp/imdb/graph_99.tsv', sep="\t") 
imdb_graph_a_adjsency_matrix = df.values
size = len(pp_train_data)
imdb_graph_a = np.zeros((size, size))
for row in imdb_graph_a_adjsency_matrix:
  imdb_graph_a[int(row[0]),int(row[1])] = row[2]

# %%
max_seq_length_slice = 256
# pp_train_data_sliced = np.zeros((len(pp_train_data), max_seq_length_slice))
# i = 0
# while i < len(pp_train_data):
#   if len(pp_train_data[i]) > max_seq_length_slice:
#     pp_train_data_sliced[i] = pp_train_data[i][:max_seq_length_slice]
#   else:
#     pp_train_data_sliced[i] = np.append(np.array(pp_train_data[i]), np.zeros(max_seq_length_slice - len(pp_train_data[i])))
#   i = i + 1

# %%
print(len(bertEmbeddings_np),len(bertEmbeddings_np[0]))
print(bertEmbeddings_np.shape)
# Out:
# 1000 128
# (1000, 128)

# %%
pp_train_labels_binary = np.zeros((len(pp_train_labels),2))
j = 0
for _ in pp_train_labels:
  if _ == 1:
    pp_train_labels_binary[j][1] = 1
  else:
    pp_train_labels_binary[j][0] = 1
  j = j + 1

# %%
imdb_graph=Graph(a=imdb_graph_a, x=bertEmbeddings_np, y=pp_train_labels_binary)

# %%
class MyDataset(Dataset):
    """
    A dataset of five random graphs.
    """
    def __init__(self, **kwargs):
        # self.nodes = nodes
        # self.feats = feats

        super().__init__(**kwargs)

    def download(self):
        # data = ...  # Download from somewhere
        path = '/tmp/imdb'
        # Create the directory
        
        # os.mkdir(path)
        filename = os.path.join(path, 'imdb_graph')
        np.savez(filename, x=imdb_graph.x, a=imdb_graph.a, y=imdb_graph.y)

    def read(self):
        # We must return a list of Graph objects
        output = []

        # for i in range(5):
        #     data = np.load(os.path.join(self.path, f'graph_{i}.npz'))
        #     output.append(
        #         Graph(x=data['x'], a=data['a'], y=data['y'])
        #     )
        output.append(imdb_graph)
        return output

# %%
dataset = MyDataset()
dataset[0]
dataset.apply(GCNFilter())

# %%
dataset[0].x.shape
# Out:
# (1000, 128)

# %% [markdown]
# ## Train the model

# %%
from tensorflow.keras.optimizers import SGD
learning_rate = 5e-3
seed = 0
epochs = 2000
patience = 10

tf.random.set_seed(seed=seed)  # make weight initialization reproducible

# %%
model = GCN(n_labels=imdb_graph.n_labels)

# %%
model.compile(
    optimizer=Adam(learning_rate),
    loss=tf.keras.losses.BinaryCrossentropy(),
    weighted_metrics=["acc"],
)

# %%
# Train model
loader_tr = SingleLoader(dataset)
model.fit(
    loader_tr.load(),
    steps_per_epoch=loader_tr.steps_per_epoch,
    epochs=epochs,
    # callbacks=[EarlyStopping(patience=patience, restore_best_weights=True)],
)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 1s 593ms/step - loss: 1.3178 - acc: 0.4850
# Epoch 2/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.1632 - acc: 0.4810
# Epoch 3/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9564 - acc: 0.4940
# Epoch 4/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.8706 - acc: 0.4770
# Epoch 5/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.8150 - acc: 0.5090
# Epoch 6/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.8019 - acc: 0.4920
# Epoch 7/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7694 - acc: 0.5140
# Epoch 8/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7497 - acc: 0.5090
# Epoch 9/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7338 - acc: 0.4980
# Epoch 10/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.7269 - acc: 0.5070
# Epoch 11/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7166 - acc: 0.5180
# Epoch 12/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7101 - acc: 0.5040
# Epoch 13/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7024 - acc: 0.5110
# Epoch 14/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7077 - acc: 0.4920
# Epoch 15/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7030 - acc: 0.5050
# Epoch 16/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6997 - acc: 0.5110
# Epoch 17/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7026 - acc: 0.5030
# Epoch 18/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6994 - acc: 0.5140
# Epoch 19/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.7007 - acc: 0.5080
# Epoch 20/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7007 - acc: 0.5040
# Epoch 21/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7016 - acc: 0.4990
# Epoch 22/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7003 - acc: 0.5070
# Epoch 23/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7013 - acc: 0.5110
# Epoch 24/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.7004 - acc: 0.5080
# Epoch 25/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7005 - acc: 0.5080
# Epoch 26/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7003 - acc: 0.5060
# Epoch 27/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7004 - acc: 0.5060
# Epoch 28/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7016 - acc: 0.5030
# Epoch 29/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7000 - acc: 0.5070
# Epoch 30/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7001 - acc: 0.5070
# Epoch 31/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7006 - acc: 0.5040
# Epoch 32/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7004 - acc: 0.5060
# Epoch 33/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7000 - acc: 0.5070
# Epoch 34/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6997 - acc: 0.5100
# Epoch 35/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7002 - acc: 0.5060
# Epoch 36/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7006 - acc: 0.5050
# Epoch 37/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6998 - acc: 0.5060
# Epoch 38/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7007 - acc: 0.5060
# Epoch 39/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7000 - acc: 0.5100
# Epoch 40/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6996 - acc: 0.5090
# Epoch 41/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6997 - acc: 0.5050
# Epoch 42/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.7002 - acc: 0.5060
# Epoch 43/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6994 - acc: 0.5080
# Epoch 44/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6996 - acc: 0.5070
# Epoch 45/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6994 - acc: 0.5060
# Epoch 46/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7003 - acc: 0.5070
# Epoch 47/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6993 - acc: 0.5050
# Epoch 48/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6997 - acc: 0.5060
# Epoch 49/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6994 - acc: 0.5050
# Epoch 50/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6985 - acc: 0.5080
# Epoch 51/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6994 - acc: 0.5110
# Epoch 52/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6988 - acc: 0.5070
# Epoch 53/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6977 - acc: 0.5080
# Epoch 54/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6974 - acc: 0.5040
# Epoch 55/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6963 - acc: 0.5080
# Epoch 56/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6978 - acc: 0.5070
# Epoch 57/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6959 - acc: 0.5090
# Epoch 58/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6991 - acc: 0.5010
# Epoch 59/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6960 - acc: 0.5100
# Epoch 60/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6996 - acc: 0.5060
# Epoch 61/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6980 - acc: 0.5100
# Epoch 62/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6929 - acc: 0.5060
# Epoch 63/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6966 - acc: 0.5090
# Epoch 64/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6985 - acc: 0.5070
# Epoch 65/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6968 - acc: 0.5080
# Epoch 66/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6989 - acc: 0.5050
# Epoch 67/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6978 - acc: 0.5090
# Epoch 68/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6948 - acc: 0.5050
# Epoch 69/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6959 - acc: 0.5070
# Epoch 70/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6967 - acc: 0.5060
# Epoch 71/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6952 - acc: 0.5070
# Epoch 72/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6949 - acc: 0.5090
# Epoch 73/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6951 - acc: 0.5050
# Epoch 74/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6934 - acc: 0.5050
# Epoch 75/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6947 - acc: 0.5040
# Epoch 76/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6949 - acc: 0.5090
# Epoch 77/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6979 - acc: 0.5100
# Epoch 78/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6960 - acc: 0.5000
# Epoch 79/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6946 - acc: 0.5060
# Epoch 80/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6952 - acc: 0.5060
# Epoch 81/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6956 - acc: 0.5070
# Epoch 82/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6994 - acc: 0.5060
# Epoch 83/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6957 - acc: 0.5090
# Epoch 84/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6951 - acc: 0.5030
# Epoch 85/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6951 - acc: 0.5090
# Epoch 86/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6962 - acc: 0.5080
# Epoch 87/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6964 - acc: 0.5060
# Epoch 88/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6937 - acc: 0.5050
# Epoch 89/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6955 - acc: 0.5040
# Epoch 90/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6931 - acc: 0.5040
# Epoch 91/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6957 - acc: 0.5050
# Epoch 92/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6934 - acc: 0.5050
# Epoch 93/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6919 - acc: 0.5090
# Epoch 94/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6933 - acc: 0.5060
# Epoch 95/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6943 - acc: 0.5030
# Epoch 96/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6920 - acc: 0.5080
# Epoch 97/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6944 - acc: 0.5060
# Epoch 98/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6916 - acc: 0.5090
# Epoch 99/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6951 - acc: 0.5060
# Epoch 100/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6888 - acc: 0.5070
# Epoch 101/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6921 - acc: 0.5080
# Epoch 102/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6958 - acc: 0.5060
# Epoch 103/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6940 - acc: 0.5040
# Epoch 104/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6942 - acc: 0.5040
# Epoch 105/2000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6906 - acc: 0.5060
# Epoch 106/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6941 - acc: 0.5050
# Epoch 107/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6951 - acc: 0.5060
# Epoch 108/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6905 - acc: 0.5050
# Epoch 109/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6939 - acc: 0.5040
# Epoch 110/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6919 - acc: 0.5050
# Epoch 111/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6924 - acc: 0.5080
# Epoch 112/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6905 - acc: 0.5050
# Epoch 113/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6912 - acc: 0.5050
# Epoch 114/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6933 - acc: 0.5060
# Epoch 115/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6917 - acc: 0.5080
# Epoch 116/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6944 - acc: 0.5060
# Epoch 117/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6934 - acc: 0.5070
# Epoch 118/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6953 - acc: 0.5070
# Epoch 119/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6903 - acc: 0.5050
# Epoch 120/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6897 - acc: 0.5060
# Epoch 121/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6895 - acc: 0.5050
# Epoch 122/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6936 - acc: 0.5050
# Epoch 123/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6938 - acc: 0.5030
# Epoch 124/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6884 - acc: 0.5080
# Epoch 125/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6957 - acc: 0.5060
# Epoch 126/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6938 - acc: 0.5090
# Epoch 127/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6933 - acc: 0.5050
# Epoch 128/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6958 - acc: 0.5090
# Epoch 129/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6932 - acc: 0.5030
# Epoch 130/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6901 - acc: 0.5030
# Epoch 131/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6921 - acc: 0.5060
# Epoch 132/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6937 - acc: 0.5090
# Epoch 133/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6896 - acc: 0.5040
# Epoch 134/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6900 - acc: 0.5040
# Epoch 135/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6919 - acc: 0.5040
# Epoch 136/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6910 - acc: 0.5070
# Epoch 137/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6937 - acc: 0.5090
# Epoch 138/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6918 - acc: 0.5070
# Epoch 139/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6898 - acc: 0.5060
# Epoch 140/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6890 - acc: 0.5080
# Epoch 141/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6871 - acc: 0.5070
# Epoch 142/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6883 - acc: 0.5060
# Epoch 143/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6915 - acc: 0.5050
# Epoch 144/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6850 - acc: 0.5090
# Epoch 145/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6874 - acc: 0.5080
# Epoch 146/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6948 - acc: 0.5070
# Epoch 147/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6918 - acc: 0.5070
# Epoch 148/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6938 - acc: 0.5030
# Epoch 149/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6922 - acc: 0.5040
# Epoch 150/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6900 - acc: 0.5070
# Epoch 151/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6890 - acc: 0.5050
# Epoch 152/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6891 - acc: 0.5070
# Epoch 153/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6932 - acc: 0.5060
# Epoch 154/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6907 - acc: 0.5070
# Epoch 155/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6897 - acc: 0.5090
# Epoch 156/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6949 - acc: 0.5090
# Epoch 157/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6851 - acc: 0.5080
# Epoch 158/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6888 - acc: 0.5030
# Epoch 159/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6870 - acc: 0.5070
# Epoch 160/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6894 - acc: 0.5080
# Epoch 161/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6923 - acc: 0.5070
# Epoch 162/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6899 - acc: 0.5040
# Epoch 163/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6947 - acc: 0.5020
# Epoch 164/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6852 - acc: 0.5040
# Epoch 165/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6887 - acc: 0.5070
# Epoch 166/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6911 - acc: 0.5090
# Epoch 167/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6834 - acc: 0.5050
# Epoch 168/2000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6857 - acc: 0.5080
# Epoch 169/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6879 - acc: 0.5080
# Epoch 170/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6833 - acc: 0.5010
# Epoch 171/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6879 - acc: 0.5120
# Epoch 172/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6943 - acc: 0.5060
# Epoch 173/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6946 - acc: 0.5080
# Epoch 174/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6839 - acc: 0.5070
# Epoch 175/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6809 - acc: 0.5090
# Epoch 176/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6918 - acc: 0.5090
# Epoch 177/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6814 - acc: 0.5080
# Epoch 178/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6896 - acc: 0.5070
# Epoch 179/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6859 - acc: 0.5050
# Epoch 180/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6873 - acc: 0.5050
# Epoch 181/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6960 - acc: 0.5080
# Epoch 182/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6859 - acc: 0.5080
# Epoch 183/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6904 - acc: 0.5050
# Epoch 184/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6871 - acc: 0.5040
# Epoch 185/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6844 - acc: 0.5100
# Epoch 186/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6839 - acc: 0.5050
# Epoch 187/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6846 - acc: 0.5080
# Epoch 188/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6883 - acc: 0.5060
# Epoch 189/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6848 - acc: 0.5110
# Epoch 190/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6952 - acc: 0.5090
# Epoch 191/2000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6828 - acc: 0.5080
# Epoch 192/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6921 - acc: 0.5070
# Epoch 193/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6886 - acc: 0.5070
# Epoch 194/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6949 - acc: 0.5040
# Epoch 195/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6887 - acc: 0.5050
# Epoch 196/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6933 - acc: 0.5040
# Epoch 197/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6905 - acc: 0.5050
# Epoch 198/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6901 - acc: 0.5060
# Epoch 199/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6858 - acc: 0.5130
# Epoch 200/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6881 - acc: 0.5080
# Epoch 201/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6860 - acc: 0.5050
# Epoch 202/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6875 - acc: 0.5070
# Epoch 203/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6900 - acc: 0.5070
# Epoch 204/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6928 - acc: 0.5050
# Epoch 205/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6897 - acc: 0.5110
# Epoch 206/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6884 - acc: 0.5050
# Epoch 207/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6865 - acc: 0.5100
# Epoch 208/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6880 - acc: 0.5070
# Epoch 209/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6866 - acc: 0.5040
# Epoch 210/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6930 - acc: 0.5070
# Epoch 211/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6899 - acc: 0.5070
# Epoch 212/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6883 - acc: 0.5060
# Epoch 213/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6919 - acc: 0.5030
# Epoch 214/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6901 - acc: 0.5040
# Epoch 215/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6892 - acc: 0.5070
# Epoch 216/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6905 - acc: 0.5070
# Epoch 217/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6939 - acc: 0.5120
# Epoch 218/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6891 - acc: 0.5090
# Epoch 219/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6892 - acc: 0.5090
# Epoch 220/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6903 - acc: 0.5090
# Epoch 221/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6847 - acc: 0.5080
# Epoch 222/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6867 - acc: 0.5090
# Epoch 223/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6825 - acc: 0.5120
# Epoch 224/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6826 - acc: 0.5060
# Epoch 225/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6896 - acc: 0.5070
# Epoch 226/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6889 - acc: 0.5110
# Epoch 227/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6861 - acc: 0.5110
# Epoch 228/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6956 - acc: 0.5070
# Epoch 229/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6931 - acc: 0.5140
# Epoch 230/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6853 - acc: 0.5110
# Epoch 231/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6920 - acc: 0.5030
# Epoch 232/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6890 - acc: 0.5220
# Epoch 233/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6930 - acc: 0.5060
# Epoch 234/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6920 - acc: 0.4980
# Epoch 235/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6952 - acc: 0.5090
# Epoch 236/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6909 - acc: 0.5040
# Epoch 237/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6855 - acc: 0.5110
# Epoch 238/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6865 - acc: 0.5090
# Epoch 239/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6913 - acc: 0.5040
# Epoch 240/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6913 - acc: 0.5100
# Epoch 241/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6894 - acc: 0.5070
# Epoch 242/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6884 - acc: 0.5050
# Epoch 243/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6873 - acc: 0.5090
# Epoch 244/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6846 - acc: 0.5070
# Epoch 245/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6860 - acc: 0.5090
# Epoch 246/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6892 - acc: 0.5090
# Epoch 247/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6854 - acc: 0.5060
# Epoch 248/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6909 - acc: 0.5090
# Epoch 249/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6922 - acc: 0.5070
# Epoch 250/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6894 - acc: 0.5100
# Epoch 251/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6936 - acc: 0.5070
# Epoch 252/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6871 - acc: 0.5050
# Epoch 253/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6942 - acc: 0.5070
# Epoch 254/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6858 - acc: 0.5030
# Epoch 255/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6931 - acc: 0.5050
# Epoch 256/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6880 - acc: 0.5110
# Epoch 257/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6840 - acc: 0.5040
# Epoch 258/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6890 - acc: 0.5070
# Epoch 259/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6863 - acc: 0.5090
# Epoch 260/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6840 - acc: 0.5070
# Epoch 261/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6874 - acc: 0.5050
# Epoch 262/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6876 - acc: 0.5050
# Epoch 263/2000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6907 - acc: 0.5120
# Epoch 264/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6899 - acc: 0.5070
# Epoch 265/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6867 - acc: 0.5110
# Epoch 266/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6948 - acc: 0.5110
# Epoch 267/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6885 - acc: 0.5070
# Epoch 268/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6873 - acc: 0.5080
# Epoch 269/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6943 - acc: 0.5070
# Epoch 270/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6858 - acc: 0.5110
# Epoch 271/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6864 - acc: 0.5070
# Epoch 272/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6900 - acc: 0.5120
# Epoch 273/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6869 - acc: 0.5110
# Epoch 274/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6890 - acc: 0.5020
# Epoch 275/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6949 - acc: 0.5030
# Epoch 276/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6931 - acc: 0.5040
# Epoch 277/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6876 - acc: 0.5090
# Epoch 278/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6889 - acc: 0.5060
# Epoch 279/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6863 - acc: 0.5100
# Epoch 280/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6893 - acc: 0.5090
# Epoch 281/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6945 - acc: 0.5060
# Epoch 282/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6896 - acc: 0.5070
# Epoch 283/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6835 - acc: 0.5060
# Epoch 284/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6905 - acc: 0.5080
# Epoch 285/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6890 - acc: 0.5060
# Epoch 286/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6890 - acc: 0.5100
# Epoch 287/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6908 - acc: 0.5020
# Epoch 288/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6929 - acc: 0.5060
# Epoch 289/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6816 - acc: 0.5140
# Epoch 290/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6882 - acc: 0.5100
# Epoch 291/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6887 - acc: 0.5090
# Epoch 292/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6839 - acc: 0.5040
# Epoch 293/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6867 - acc: 0.5060
# Epoch 294/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6874 - acc: 0.5050
# Epoch 295/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6840 - acc: 0.5080
# Epoch 296/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6830 - acc: 0.5120
# Epoch 297/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6884 - acc: 0.5100
# Epoch 298/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6870 - acc: 0.5110
# Epoch 299/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6863 - acc: 0.5110
# Epoch 300/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6821 - acc: 0.5080
# Epoch 301/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6935 - acc: 0.4990
# Epoch 302/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6874 - acc: 0.5110
# Epoch 303/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6851 - acc: 0.5140
# Epoch 304/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6867 - acc: 0.5180
# Epoch 305/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6846 - acc: 0.5190
# Epoch 306/2000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6852 - acc: 0.5240
# Epoch 307/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6881 - acc: 0.5130
# Epoch 308/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6850 - acc: 0.5180
# Epoch 309/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6907 - acc: 0.5010
# Epoch 310/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6885 - acc: 0.4950
# Epoch 311/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6893 - acc: 0.5070
# Epoch 312/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6937 - acc: 0.5170
# Epoch 313/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6902 - acc: 0.5030
# Epoch 314/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6892 - acc: 0.5080
# Epoch 315/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6879 - acc: 0.5250
# Epoch 316/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6852 - acc: 0.5220
# Epoch 317/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6894 - acc: 0.5100
# Epoch 318/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6821 - acc: 0.5170
# Epoch 319/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6859 - acc: 0.5110
# Epoch 320/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6870 - acc: 0.5100
# Epoch 321/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6876 - acc: 0.5040
# Epoch 322/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6834 - acc: 0.5380
# Epoch 323/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6857 - acc: 0.5270
# Epoch 324/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6816 - acc: 0.5000
# Epoch 325/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6852 - acc: 0.5100
# Epoch 326/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6869 - acc: 0.5150
# Epoch 327/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6822 - acc: 0.5170
# Epoch 328/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6857 - acc: 0.5440
# Epoch 329/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6817 - acc: 0.5340
# Epoch 330/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6841 - acc: 0.5320
# Epoch 331/2000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6862 - acc: 0.5370
# Epoch 332/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6818 - acc: 0.5380
# Epoch 333/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6884 - acc: 0.5130
# Epoch 334/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6853 - acc: 0.5360
# Epoch 335/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6892 - acc: 0.5170
# Epoch 336/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6850 - acc: 0.5290
# Epoch 337/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6854 - acc: 0.5440
# Epoch 338/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6875 - acc: 0.5300
# Epoch 339/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6816 - acc: 0.5190
# Epoch 340/2000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6820 - acc: 0.5510
# Epoch 341/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6821 - acc: 0.5380
# Epoch 342/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6818 - acc: 0.5110
# Epoch 343/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6820 - acc: 0.5670
# Epoch 344/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6760 - acc: 0.5660
# Epoch 345/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6802 - acc: 0.5560
# Epoch 346/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6826 - acc: 0.5690
# Epoch 347/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6942 - acc: 0.5400
# Epoch 348/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6881 - acc: 0.5360
# Epoch 349/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6868 - acc: 0.5420
# Epoch 350/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6869 - acc: 0.5310
# Epoch 351/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6802 - acc: 0.5500
# Epoch 352/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6777 - acc: 0.5480
# Epoch 353/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6763 - acc: 0.5350
# Epoch 354/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6855 - acc: 0.5320
# Epoch 355/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6747 - acc: 0.5590
# Epoch 356/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6781 - acc: 0.5320
# Epoch 357/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6899 - acc: 0.5360
# Epoch 358/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6814 - acc: 0.5470
# Epoch 359/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6809 - acc: 0.5580
# Epoch 360/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6711 - acc: 0.5760
# Epoch 361/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6860 - acc: 0.5400
# Epoch 362/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6868 - acc: 0.5500
# Epoch 363/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6861 - acc: 0.5410
# Epoch 364/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6789 - acc: 0.5590
# Epoch 365/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6795 - acc: 0.5260
# Epoch 366/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6786 - acc: 0.5530
# Epoch 367/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6778 - acc: 0.5600
# Epoch 368/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6812 - acc: 0.5450
# Epoch 369/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6736 - acc: 0.5670
# Epoch 370/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6842 - acc: 0.5650
# Epoch 371/2000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6828 - acc: 0.5530
# Epoch 372/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6887 - acc: 0.5210
# Epoch 373/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6779 - acc: 0.5530
# Epoch 374/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6723 - acc: 0.5600
# Epoch 375/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6741 - acc: 0.5640
# Epoch 376/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6760 - acc: 0.5640
# Epoch 377/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6752 - acc: 0.5810
# Epoch 378/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6663 - acc: 0.5660
# Epoch 379/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6867 - acc: 0.5440
# Epoch 380/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6785 - acc: 0.5590
# Epoch 381/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6755 - acc: 0.5610
# Epoch 382/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6775 - acc: 0.5540
# Epoch 383/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6721 - acc: 0.5690
# Epoch 384/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6896 - acc: 0.5490
# Epoch 385/2000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6868 - acc: 0.5460
# Epoch 386/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6705 - acc: 0.5540
# Epoch 387/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6785 - acc: 0.5730
# Epoch 388/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6815 - acc: 0.5510
# Epoch 389/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6697 - acc: 0.5790
# Epoch 390/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6885 - acc: 0.5280
# Epoch 391/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6736 - acc: 0.5710
# Epoch 392/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6737 - acc: 0.5750
# Epoch 393/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6845 - acc: 0.5470
# Epoch 394/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6805 - acc: 0.5750
# Epoch 395/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6696 - acc: 0.5710
# Epoch 396/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6708 - acc: 0.5560
# Epoch 397/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6901 - acc: 0.5610
# Epoch 398/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6755 - acc: 0.5520
# Epoch 399/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6767 - acc: 0.5710
# Epoch 400/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6787 - acc: 0.5520
# Epoch 401/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6920 - acc: 0.5550
# Epoch 402/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6832 - acc: 0.5550
# Epoch 403/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6744 - acc: 0.5740
# Epoch 404/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6711 - acc: 0.5970
# Epoch 405/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6701 - acc: 0.5770
# Epoch 406/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6861 - acc: 0.5480
# Epoch 407/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6731 - acc: 0.5780
# Epoch 408/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6750 - acc: 0.5680
# Epoch 409/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6723 - acc: 0.5800
# Epoch 410/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6642 - acc: 0.5880
# Epoch 411/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6788 - acc: 0.5660
# Epoch 412/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6799 - acc: 0.5510
# Epoch 413/2000
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6867 - acc: 0.5390
# Epoch 414/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6845 - acc: 0.5420
# Epoch 415/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6768 - acc: 0.5830
# Epoch 416/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6711 - acc: 0.5960
# Epoch 417/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6736 - acc: 0.5670
# Epoch 418/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6708 - acc: 0.5780
# Epoch 419/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6707 - acc: 0.5890
# Epoch 420/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6707 - acc: 0.5930
# Epoch 421/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6740 - acc: 0.5720
# Epoch 422/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6729 - acc: 0.5700
# Epoch 423/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6759 - acc: 0.5650
# Epoch 424/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6879 - acc: 0.5620
# Epoch 425/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6709 - acc: 0.5880
# Epoch 426/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6763 - acc: 0.5790
# Epoch 427/2000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6789 - acc: 0.5820
# Epoch 428/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6725 - acc: 0.5590
# Epoch 429/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6804 - acc: 0.5620
# Epoch 430/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6720 - acc: 0.5860
# Epoch 431/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6773 - acc: 0.5510
# Epoch 432/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6737 - acc: 0.5740
# Epoch 433/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6726 - acc: 0.5770
# Epoch 434/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6740 - acc: 0.5750
# Epoch 435/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6755 - acc: 0.5540
# Epoch 436/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6776 - acc: 0.5580
# Epoch 437/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6760 - acc: 0.5780
# Epoch 438/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6729 - acc: 0.5620
# Epoch 439/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6750 - acc: 0.5710
# Epoch 440/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6760 - acc: 0.5810
# Epoch 441/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6724 - acc: 0.5880
# Epoch 442/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6811 - acc: 0.5740
# Epoch 443/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6740 - acc: 0.5830
# Epoch 444/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6675 - acc: 0.5920
# Epoch 445/2000
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6769 - acc: 0.5840
# Epoch 446/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6774 - acc: 0.5780
# Epoch 447/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6770 - acc: 0.5600
# Epoch 448/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6712 - acc: 0.5720
# Epoch 449/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6687 - acc: 0.5880
# Epoch 450/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6629 - acc: 0.5940
# Epoch 451/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6656 - acc: 0.5670
# Epoch 452/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6770 - acc: 0.6070
# Epoch 453/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6880 - acc: 0.5420
# Epoch 454/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6534 - acc: 0.6120
# Epoch 455/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6741 - acc: 0.5750
# Epoch 456/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6698 - acc: 0.5840
# Epoch 457/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6769 - acc: 0.5960
# Epoch 458/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6823 - acc: 0.5690
# Epoch 459/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6801 - acc: 0.5830
# Epoch 460/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6762 - acc: 0.5650
# Epoch 461/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6775 - acc: 0.5730
# Epoch 462/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6794 - acc: 0.5710
# Epoch 463/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6694 - acc: 0.5880
# Epoch 464/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6768 - acc: 0.5830
# Epoch 465/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6716 - acc: 0.5860
# Epoch 466/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6797 - acc: 0.5670
# Epoch 467/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6614 - acc: 0.5940
# Epoch 468/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6683 - acc: 0.5790
# Epoch 469/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6758 - acc: 0.5680
# Epoch 470/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6799 - acc: 0.5720
# Epoch 471/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6844 - acc: 0.5650
# Epoch 472/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6760 - acc: 0.5860
# Epoch 473/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6762 - acc: 0.5770
# Epoch 474/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6686 - acc: 0.5980
# Epoch 475/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6710 - acc: 0.5690
# Epoch 476/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6695 - acc: 0.5940
# Epoch 477/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6724 - acc: 0.5830
# Epoch 478/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6696 - acc: 0.5690
# Epoch 479/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6754 - acc: 0.5670
# Epoch 480/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6815 - acc: 0.5830
# Epoch 481/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6775 - acc: 0.5710
# Epoch 482/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6690 - acc: 0.5970
# Epoch 483/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6793 - acc: 0.5620
# Epoch 484/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6686 - acc: 0.5840
# Epoch 485/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6730 - acc: 0.5760
# Epoch 486/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6742 - acc: 0.5750
# Epoch 487/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6601 - acc: 0.5940
# Epoch 488/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6738 - acc: 0.5720
# Epoch 489/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6760 - acc: 0.5650
# Epoch 490/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6753 - acc: 0.5820
# Epoch 491/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6728 - acc: 0.5960
# Epoch 492/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6739 - acc: 0.5750
# Epoch 493/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6609 - acc: 0.6060
# Epoch 494/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6700 - acc: 0.5820
# Epoch 495/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6839 - acc: 0.5570
# Epoch 496/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6825 - acc: 0.5600
# Epoch 497/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6633 - acc: 0.6080
# Epoch 498/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6659 - acc: 0.5920
# Epoch 499/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6723 - acc: 0.5820
# Epoch 500/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6716 - acc: 0.5840
# Epoch 501/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6724 - acc: 0.5710
# ...
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6707 - acc: 0.5820
# Epoch 1837/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6644 - acc: 0.5840
# Epoch 1838/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6638 - acc: 0.6020
# Epoch 1839/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6678 - acc: 0.5860
# Epoch 1840/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6659 - acc: 0.6060
# Epoch 1841/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6687 - acc: 0.5990
# Epoch 1842/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6772 - acc: 0.5800
# Epoch 1843/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6757 - acc: 0.5780
# Epoch 1844/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6654 - acc: 0.5950
# Epoch 1845/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6671 - acc: 0.5790
# Epoch 1846/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6609 - acc: 0.6080
# Epoch 1847/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6644 - acc: 0.5860
# Epoch 1848/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6701 - acc: 0.5840
# Epoch 1849/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6582 - acc: 0.5980
# Epoch 1850/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6685 - acc: 0.6030
# Epoch 1851/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6727 - acc: 0.6090
# Epoch 1852/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6651 - acc: 0.5920
# Epoch 1853/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6748 - acc: 0.5730
# Epoch 1854/2000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6646 - acc: 0.5820
# Epoch 1855/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6682 - acc: 0.5730
# Epoch 1856/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6617 - acc: 0.5830
# Epoch 1857/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6685 - acc: 0.5870
# Epoch 1858/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6632 - acc: 0.5920
# Epoch 1859/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6604 - acc: 0.6010
# Epoch 1860/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6725 - acc: 0.5820
# Epoch 1861/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6564 - acc: 0.6120
# Epoch 1862/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6740 - acc: 0.5860
# Epoch 1863/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6754 - acc: 0.5570
# Epoch 1864/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6670 - acc: 0.5880
# Epoch 1865/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6614 - acc: 0.5890
# Epoch 1866/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6738 - acc: 0.6180
# Epoch 1867/2000
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6627 - acc: 0.6050
# Epoch 1868/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6612 - acc: 0.6260
# Epoch 1869/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6610 - acc: 0.5980
# Epoch 1870/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6651 - acc: 0.5920
# Epoch 1871/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6665 - acc: 0.5980
# Epoch 1872/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6677 - acc: 0.6030
# Epoch 1873/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6671 - acc: 0.5830
# Epoch 1874/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6595 - acc: 0.5930
# Epoch 1875/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6718 - acc: 0.5630
# Epoch 1876/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6714 - acc: 0.5710
# Epoch 1877/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6714 - acc: 0.5840
# Epoch 1878/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6717 - acc: 0.5850
# Epoch 1879/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6691 - acc: 0.5780
# Epoch 1880/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6758 - acc: 0.5600
# Epoch 1881/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6679 - acc: 0.5760
# Epoch 1882/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6741 - acc: 0.5750
# Epoch 1883/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6708 - acc: 0.5800
# Epoch 1884/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6690 - acc: 0.5900
# Epoch 1885/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6596 - acc: 0.6060
# Epoch 1886/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6585 - acc: 0.5950
# Epoch 1887/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6652 - acc: 0.5790
# Epoch 1888/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6698 - acc: 0.5630
# Epoch 1889/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6662 - acc: 0.5810
# Epoch 1890/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6789 - acc: 0.5590
# Epoch 1891/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6648 - acc: 0.5880
# Epoch 1892/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6666 - acc: 0.5820
# Epoch 1893/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6552 - acc: 0.5960
# Epoch 1894/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6559 - acc: 0.6080
# Epoch 1895/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6609 - acc: 0.6080
# Epoch 1896/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6639 - acc: 0.6080
# Epoch 1897/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6735 - acc: 0.5930
# Epoch 1898/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6562 - acc: 0.6090
# Epoch 1899/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6608 - acc: 0.5990
# Epoch 1900/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6833 - acc: 0.5830
# Epoch 1901/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6692 - acc: 0.5730
# Epoch 1902/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6633 - acc: 0.5990
# Epoch 1903/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6693 - acc: 0.5720
# Epoch 1904/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6604 - acc: 0.5970
# Epoch 1905/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6624 - acc: 0.6180
# Epoch 1906/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6652 - acc: 0.5820
# Epoch 1907/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6654 - acc: 0.5920
# Epoch 1908/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6763 - acc: 0.5440
# Epoch 1909/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6721 - acc: 0.5740
# Epoch 1910/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6645 - acc: 0.6010
# Epoch 1911/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6758 - acc: 0.5620
# Epoch 1912/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6698 - acc: 0.5610
# Epoch 1913/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6667 - acc: 0.5810
# Epoch 1914/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6671 - acc: 0.5950
# Epoch 1915/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6701 - acc: 0.5940
# Epoch 1916/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6724 - acc: 0.5750
# Epoch 1917/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6786 - acc: 0.5680
# Epoch 1918/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6736 - acc: 0.6020
# Epoch 1919/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6687 - acc: 0.5670
# Epoch 1920/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6592 - acc: 0.6010
# Epoch 1921/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6581 - acc: 0.6110
# Epoch 1922/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6798 - acc: 0.5690
# Epoch 1923/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6642 - acc: 0.5930
# Epoch 1924/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6645 - acc: 0.5790
# Epoch 1925/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6553 - acc: 0.6050
# Epoch 1926/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6662 - acc: 0.5830
# Epoch 1927/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6805 - acc: 0.5850
# Epoch 1928/2000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6655 - acc: 0.5810
# Epoch 1929/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6649 - acc: 0.6000
# Epoch 1930/2000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6541 - acc: 0.6080
# Epoch 1931/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6669 - acc: 0.5870
# Epoch 1932/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6690 - acc: 0.6000
# Epoch 1933/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6667 - acc: 0.5960
# Epoch 1934/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6705 - acc: 0.5680
# Epoch 1935/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6684 - acc: 0.6040
# Epoch 1936/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6644 - acc: 0.5800
# Epoch 1937/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6821 - acc: 0.5560
# Epoch 1938/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6777 - acc: 0.5760
# Epoch 1939/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6714 - acc: 0.5910
# Epoch 1940/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6632 - acc: 0.5840
# Epoch 1941/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6716 - acc: 0.5770
# Epoch 1942/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6658 - acc: 0.6130
# Epoch 1943/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6737 - acc: 0.5850
# Epoch 1944/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6631 - acc: 0.5990
# Epoch 1945/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6740 - acc: 0.5820
# Epoch 1946/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6693 - acc: 0.5970
# Epoch 1947/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6613 - acc: 0.5970
# Epoch 1948/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6547 - acc: 0.6070
# Epoch 1949/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6736 - acc: 0.5840
# Epoch 1950/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6647 - acc: 0.6020
# Epoch 1951/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6633 - acc: 0.5890
# Epoch 1952/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6799 - acc: 0.5810
# Epoch 1953/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6731 - acc: 0.5730
# Epoch 1954/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6624 - acc: 0.5910
# Epoch 1955/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6656 - acc: 0.5900
# Epoch 1956/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6770 - acc: 0.5620
# Epoch 1957/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6658 - acc: 0.5780
# Epoch 1958/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6639 - acc: 0.5810
# Epoch 1959/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6655 - acc: 0.5780
# Epoch 1960/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6672 - acc: 0.6070
# Epoch 1961/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6667 - acc: 0.6020
# Epoch 1962/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6697 - acc: 0.5710
# Epoch 1963/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6713 - acc: 0.5800
# Epoch 1964/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6521 - acc: 0.6050
# Epoch 1965/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6616 - acc: 0.5970
# Epoch 1966/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6702 - acc: 0.6050
# Epoch 1967/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6759 - acc: 0.5980
# Epoch 1968/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6772 - acc: 0.5970
# Epoch 1969/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6651 - acc: 0.5960
# Epoch 1970/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6752 - acc: 0.5850
# Epoch 1971/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6686 - acc: 0.5960
# Epoch 1972/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6664 - acc: 0.5860
# Epoch 1973/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6642 - acc: 0.6000
# Epoch 1974/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6665 - acc: 0.5980
# Epoch 1975/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6679 - acc: 0.6120
# Epoch 1976/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6623 - acc: 0.5980
# Epoch 1977/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6751 - acc: 0.5870
# Epoch 1978/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6655 - acc: 0.5850
# Epoch 1979/2000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6630 - acc: 0.6140
# Epoch 1980/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6719 - acc: 0.5910
# Epoch 1981/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6610 - acc: 0.5900
# Epoch 1982/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6577 - acc: 0.5930
# Epoch 1983/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6740 - acc: 0.5690
# Epoch 1984/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6663 - acc: 0.5990
# Epoch 1985/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6590 - acc: 0.6170
# Epoch 1986/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6707 - acc: 0.6000
# Epoch 1987/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6685 - acc: 0.5910
# Epoch 1988/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6667 - acc: 0.5890
# Epoch 1989/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6717 - acc: 0.5670
# Epoch 1990/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6755 - acc: 0.5810
# Epoch 1991/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6653 - acc: 0.5950
# Epoch 1992/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6668 - acc: 0.5780
# Epoch 1993/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6682 - acc: 0.5820
# Epoch 1994/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6695 - acc: 0.5910
# Epoch 1995/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6548 - acc: 0.6090
# Epoch 1996/2000
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6596 - acc: 0.6020
# Epoch 1997/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6610 - acc: 0.5960
# Epoch 1998/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6629 - acc: 0.6110
# Epoch 1999/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6660 - acc: 0.5900
# Epoch 2000/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6765 - acc: 0.5740

# %% [markdown]
# ## Evaluate the model

# %%
# Evaluate model
print("Evaluating model.")
loader_te = SingleLoader(dataset, sample_weights=weights_te)
eval_results = model.evaluate(loader_te.load(), steps=loader_te.steps_per_epoch)
print("Done.\n" "Test loss: {}\n" "Test accuracy: {}".format(*eval_results))
# Out:
# Evaluating model.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-237-5b03e73517cf> in <module>()
#       1 # Evaluate model
#       2 print("Evaluating model.")
# ----> 3 loader_te = SingleLoader(dataset, sample_weights=weights_te)
#       4 eval_results = model.evaluate(loader_te.load(), steps=loader_te.steps_per_epoch)
#       5 print("Done.\n" "Test loss: {}\n" "Test accuracy: {}".format(*eval_results))
#
# NameError: name 'weights_te' is not defined
